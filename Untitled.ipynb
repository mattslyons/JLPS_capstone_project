# %%
# %matplotlib inline

import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
from IPython.display import display

from arcgis.gis import GIS
from arcgis.features.analyze_patterns import calculate_density, find_hot_spots
from arcgis.mapping.symbol import create_symbol
from arcgis.features.use_proximity import create_drive_time_areas
from arcgis.features.summarize_data import summarize_within

# %%
gis = GIS(url="https://cal.maps.arcgis.com", username="mattslyons", password="S2mer$ault6-I2_zz", verify_cert=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\arcgis\auth\_auth\_token.py:572, in EsriBuiltInAuth.token(self)
#     571 if self._response_type == "token":
# --> 572     self._init_response_type_token()
#     573 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\arcgis\auth\_auth\_token.py:361, in EsriBuiltInAuth._init_response_type_token(self)
#     360     raise ArcGISLoginError()
# --> 361 callback_url = response.headers["location"]
#     362 if callback_url.find("acceptTermsAndConditions") > -1:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\structures.py:52, in CaseInsensitiveDict.__getitem__(self, key)
#      51 def __getitem__(self, key):
# ---> 52     return self._store[key.lower()][1]
#
# KeyError: 'location'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
gis = GIS("https://www.arcgis.com", "mattslyons", "S2mer$ault6-I2_zz")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\arcgis\auth\_auth\_token.py:572, in EsriBuiltInAuth.token(self)
#     571 if self._response_type == "token":
# --> 572     self._init_response_type_token()
#     573 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\arcgis\auth\_auth\_token.py:361, in EsriBuiltInAuth._init_response_type_token(self)
#     360     raise ArcGISLoginError()
# --> 361 callback_url = response.headers["location"]
#     362 if callback_url.find("acceptTermsAndConditions") > -1:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\structures.py:52, in CaseInsensitiveDict.__getitem__(self, key)
#      51 def __getitem__(self, key):
# ---> 52     return self._store[key.lower()][1]
#
# KeyError: 'location'
#
# During handling of the above exception, another exception occurred:
#
# ...
