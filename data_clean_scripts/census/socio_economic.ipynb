# %%
import pandas as pd 
import numpy as np
import os 
import datetime
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import plotly.express as px

# %%
# local or gdrive
path_source = 'gdrive'

if path_source == 'gdrive':
  from google.colab import drive
  drive.mount('/content/gdrive')
  mapbox_path = '/content/gdrive/MyDrive/Classes/W210_capstone/.mapbox_token'
  data_path = '/content/gdrive/MyDrive/Classes/W210_capstone/W210 Capstone/Data/census'
  #os.chdir('/content/gdrive/MyDrive/Classes/W210_capstone/JLPS_capstone_project/data_clean_scripts/wind')
  plotly_out = '/content/gdrive/MyDrive/Classes/W210_capstone/plotly_gif'

elif path_source == 'local':
  maxbox_path = '/Users/tj/Documents/code/api_key/.mapbox_token'
  data_path = '/Users/tj/trevorj@berkeley.edu - Google Drive/My Drive/Classes/W210_capstone/W210 Capstone/Data/census'
  #os.chdir('/Users/tj/trevorj@berkeley.edu - Google Drive/MyDrive/Classes/W210_capstone/JLPS_capstone_project/data_clean_scripts/wind')
  plotly_out = '/Users/tj/trevorj@berkeley.edu - Google Drive/MyDrive/Classes/W210_capstone/plotly_gif'

px.set_mapbox_access_token(open(mapbox_path).read())
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv(os.path.join(data_path, 'unemployment_by_msa.csv'))
df.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          LAUS Code  ST FIPS Code  Area FIPS Code  \
# 0  MT0111500000000             1           11500
# 1  MT0112220000000             1           12220
# 2  MT0113820000000             1           13820
#
#                                    Area  Year  Month Civilian Labor Force  \
# 0  Anniston-Oxford-Jacksonville, AL MSA  1990      1               51,709
# 1                Auburn-Opelika, AL MSA  1990      1               44,426
# 2             Birmingham-Hoover, AL MSA  1990      1              460,283
#
#   Employment Unemployment Unemployment Rate
# 0     48,084        3,625               7.0
# 1     41,104        3,322               7.5
# 2    435,924       24,359               5.3

# %%
df.columns = ['laus_code', 'fips_state', 'fips_area', 'msa', 'year', 'month', 'civilian_labor_force', 'employement', 'unemployment', 'unemployment_rate']
df['civilian_labor_force'].map(lambda x: ).astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-847de9dbb868> in <module>
#       1 df.columns = ['laus_code', 'fips_state', 'fips_area', 'msa', 'year', 'month', 'civilian_labor_force', 'employement', 'unemployment', 'unemployment_rate']
# ----> 2 df['civilian_labor_force'].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %%
df.dtypes
# Out:
# laus_code               object
# fips_state               int64
# fips_area                int64
# msa                     object
# year                     int64
# month                    int64
# civilian_labor_force    object
# employement             object
# unemployment            object
# unemployment_rate       object
# dtype: object
