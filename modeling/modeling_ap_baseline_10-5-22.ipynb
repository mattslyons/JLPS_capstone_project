# %%
# basics
import pandas as pd 
import numpy as np
import os 
import re
from datetime import datetime
from tqdm.notebook import tqdm
tqdm.pandas()
import requests
import urllib

# plotting
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import plotly.express as px

# modeling
import statsmodels.api as sm

pd.set_option('display.max_columns', None)

# %%
# local or gdrive
path_source = 'local2'

if path_source == 'gdrive':
  from google.colab import drive
  drive.mount('/content/gdrive')
  data_path = '/content/gdrive/MyDrive/Classes/W210_capstone/W210_Capstone/Data/joined_data'
  #env_path = '/content/gdrive/MyDrive/.env'
  
elif path_source == 'local':
  data_path = '/Users/tj/trevorj@berkeley.edu - Google Drive/My Drive/Classes/W210_capstone/W210_Capstone/Data/joined_data'
  #env_path = '/content/gdrive/MyDrive/.env'

elif path_source == 'local2':
  data_path = '/data/joined_data'
  #env_path = '/content/gdrive/MyDrive/.env'

# %%
  
def current_path():
    print("Current working directory before")
    print(os.getcwd())
    print()
   
current_path()
   
os.chdir('../')
   
current_path()
# Out:
# Current working directory before
# c:\Users\anandadmin\Documents\ML_MS\UCB\2022_Fall\W210\JLPS_capstone_project\modeling
#
# Current working directory before
# c:\Users\anandadmin\Documents\ML_MS\UCB\2022_Fall\W210\JLPS_capstone_project

# %%
os.getcwd()
# Out:
# 'c:\\Users\\anandadmin\\Documents\\ML_MS\\UCB\\2022_Fall\\W210\\JLPS_capstone_project'

# %%
# load full dataset
df = pd.read_parquet('data\joined_data\joined_filtered_data.parquet')

# %%
df.head()
# Out:
#      year         cdscode school_county school_zip  \
# 0  2010.0  20102070109728        Madera      93610
# 1  2010.0  20102072030187        Madera      93610
# 2  2010.0  20651930000000        Madera      93610
# 3  2010.0  20651930113076        Madera      93610
# 4  2010.0  20651936023907        Madera      93610
#
#             school_region_name school_open_date school_closed_date school_lat  \
# 0  Northern San Joaquin Valley        8/16/2005          6/30/2014  37.115210
# 1  Northern San Joaquin Valley        1/22/2001          6/30/2014  37.115210
# 2  Northern San Joaquin Valley          No Data            No Data  37.122449
# 3  Northern San Joaquin Valley        8/21/2007            No Data  37.131113
# 4  Northern San Joaquin Valley         7/1/1980            No Data  37.115243
#
#     school_lon  school_wspd  school_elevation_m year_month total_population  \
# 0   -120.26603     1.531352               70.84    2010-04          23833.0
# 1   -120.26603     1.531352               70.84    2010-04          23833.0
# 2   -120.26487     1.531352               72.77    2010-04          23833.0
# 3  -120.242025     1.531352               77.12    2010-04          23833.0
# 4   -120.26777     1.531352               70.66    2010-04          23833.0
#
#   total_population_male total_population_female population_0_4  \
# 0                8280.0                 15553.0         1439.0
# 1                8280.0                 15553.0         1439.0
# 2                8280.0                 15553.0         1439.0
# 3                8280.0                 15553.0         1439.0
# 4                8280.0                 15553.0         1439.0
#
#   population_0_4_male population_0_4_female population_5_9  \
# 0               694.0                 745.0         1485.0
# 1               694.0                 745.0         1485.0
# 2               694.0                 745.0         1485.0
# 3               694.0                 745.0         1485.0
# 4               694.0                 745.0         1485.0
#
#   population_5_9_male population_5_9_female population_10_14  \
# 0               729.0                 756.0           1407.0
# 1               729.0                 756.0           1407.0
# 2               729.0                 756.0           1407.0
# 3               729.0                 756.0           1407.0
# 4               729.0                 756.0           1407.0
#
#   population_10_14_male population_10_14_female population_15_19  \
# 0                 740.0                   667.0           1473.0
# 1                 740.0                   667.0           1473.0
# 2                 740.0                   667.0           1473.0
# 3                 740.0                   667.0           1473.0
# 4                 740.0                   667.0           1473.0
#
#   population_15_19_male population_15_19_female  pop_under19_male  \
# 0                 753.0                   720.0            2916.0
# 1                 753.0                   720.0            2916.0
# 2                 753.0                   720.0            2916.0
# 3                 753.0                   720.0            2916.0
# 4                 753.0                   720.0            2916.0
#
#    pop_under19_female total_pop_under19      pm25 point_source_lat  \
# 0              2888.0            5804.0  7.736047          37.1056
# 1              2888.0            5804.0  7.736047          37.1056
# 2              2888.0            5804.0  7.736047          37.1056
# 3              2888.0            5804.0  7.736047          37.1056
# 4              2888.0            5804.0  7.736047          37.1056
#
#   point_source_lon ps_elevation_m point_source_pm25_tpy dist_school_to_ps_m  \
# 0        -120.2487           73.3             2.0127727   1873.525780181077
# 1        -120.2487           73.3             2.0127727   1873.525780181077
# 2        -120.2487           73.3             2.0127727    2358.38241919395
# 3        -120.2487           73.3             2.0127727  2892.9075458251764
# 4        -120.2487           73.3             2.0127727  2004.5665433091058
#
#       angle_to_school  ps_wind_lat  ps_wind_lon  ps_wspd_merge  \
# 0  -55.29643968357893          NaN          NaN       1.531352
# 1  -55.29643968357893          NaN          NaN       1.531352
# 2  -37.54028477906731          NaN          NaN       1.531352
# 3  11.831222108044384          NaN          NaN       1.531352
# 4  -57.72695665034661          NaN          NaN       1.531352
#
#    school_wdir_wrt_0N  ps_wdir_wrt_0N  school_wind_alignment  \
# 0          102.528057      102.528057             157.824497
# 1          102.528057      102.528057             157.824497
# 2          102.528057      102.528057             140.068342
# 3          102.528057      102.528057              90.696835
# 4          102.528057      102.528057             160.255014
#
#    ps_wind_alignment  avg_wind_speed  avg_wind_alignment  \
# 0         157.824497        1.531352          157.824497
# 1         157.824497        1.531352          157.824497
# 2         140.068342        1.531352          140.068342
# 3          90.696835        1.531352           90.696835
# 4         160.255014        1.531352          160.255014
#
#    avg_wind_alignment_cosine
# 0                   0.073968
# 1                   0.073968
# 2                   0.233189
# 3                   0.987838
# 4                   0.058794

# %% [markdown]
# # Data Clean

# %% [markdown]
# Clean the dates:
# - For schools that don't have open/close dates, just assume the school was always open by setting early/late dates.
# - Then use the school open/closed dates and filter out schools that were closed.

# %%
# func to fill in the missing school closed/open dates
def date_fill(x, start_or_end='start'):
  if x == 'No Data' and start_or_end == 'start':
    output = '1/1/1990'
  elif x == 'No Data' and start_or_end == 'end':
    output = '1/1/2025'
  else:
    output = x 

  try:
    output = datetime.strptime(output, '%m/%d/%Y')
  except:
    return None

  return output


# for all missing dates, just assume the school was always open. 
df['school_open_date'] = df['school_open_date'].progress_map(lambda x: date_fill(x, 'start'))
df['school_closed_date'] = df['school_closed_date'].progress_map(lambda x: date_fill(x, 'end'))

# convert to datetime format
# df['school_open_date'] = df['school_open_date'].progress_map(lambda x: datetime.strptime(x, '%m/%d/%Y'))
# df['school_closed_date'] = df['school_closed_date'].progress_map(lambda x: datetime.strptime(x, '%m/%d/%Y'))

# do the same for the year_month field. But use this function in case there are NAs
def strptime2(x):
  try: 
    return datetime.strptime(x, '%Y-%m')
  except:
    return None

df['year_month_date'] = df['year_month'].progress_map(strptime2)


# create logic to filter out closed schools
def is_school_open(start, end, current):
  if (start <= current) and (end >= current):
    return 1 
  else: 
    return 0 

df['is_school_open'] = df\
  .progress_apply(lambda df: is_school_open(
      df['school_open_date'], 
      df['school_closed_date'], 
      df['year_month_date']), 
    axis=1)
# Out:
#   0%|          | 0/2983111 [00:00<?, ?it/s]
#   0%|          | 0/2983111 [00:00<?, ?it/s]
#   0%|          | 0/2983111 [00:00<?, ?it/s]
#   0%|          | 0/2983111 [00:00<?, ?it/s]

# %%
# check counts
df['is_school_open'].value_counts()
# Out:
# 1    2471552
# 0     511559
# Name: is_school_open, dtype: int64

# %%
# filter out schools that aren't open
df = df[df['is_school_open'] != 0]

# %%
df.head(3)
# Out:
#      year         cdscode school_county school_zip  \
# 0  2010.0  20102070109728        Madera      93610
# 1  2010.0  20102072030187        Madera      93610
# 2  2010.0  20651930000000        Madera      93610
#
#             school_region_name school_open_date school_closed_date school_lat  \
# 0  Northern San Joaquin Valley       2005-08-16         2014-06-30  37.115210
# 1  Northern San Joaquin Valley       2001-01-22         2014-06-30  37.115210
# 2  Northern San Joaquin Valley       1990-01-01         2025-01-01  37.122449
#
#    school_lon  school_wspd  school_elevation_m year_month total_population  \
# 0  -120.26603     1.531352               70.84    2010-04          23833.0
# 1  -120.26603     1.531352               70.84    2010-04          23833.0
# 2  -120.26487     1.531352               72.77    2010-04          23833.0
#
#   total_population_male total_population_female population_0_4  \
# 0                8280.0                 15553.0         1439.0
# 1                8280.0                 15553.0         1439.0
# 2                8280.0                 15553.0         1439.0
#
#   population_0_4_male population_0_4_female population_5_9  \
# 0               694.0                 745.0         1485.0
# 1               694.0                 745.0         1485.0
# 2               694.0                 745.0         1485.0
#
#   population_5_9_male population_5_9_female population_10_14  \
# 0               729.0                 756.0           1407.0
# 1               729.0                 756.0           1407.0
# 2               729.0                 756.0           1407.0
#
#   population_10_14_male population_10_14_female population_15_19  \
# 0                 740.0                   667.0           1473.0
# 1                 740.0                   667.0           1473.0
# 2                 740.0                   667.0           1473.0
#
#   population_15_19_male population_15_19_female  pop_under19_male  \
# 0                 753.0                   720.0            2916.0
# 1                 753.0                   720.0            2916.0
# 2                 753.0                   720.0            2916.0
#
#    pop_under19_female total_pop_under19      pm25 point_source_lat  \
# 0              2888.0            5804.0  7.736047          37.1056
# 1              2888.0            5804.0  7.736047          37.1056
# 2              2888.0            5804.0  7.736047          37.1056
#
#   point_source_lon ps_elevation_m point_source_pm25_tpy dist_school_to_ps_m  \
# 0        -120.2487           73.3             2.0127727   1873.525780181077
# 1        -120.2487           73.3             2.0127727   1873.525780181077
# 2        -120.2487           73.3             2.0127727    2358.38241919395
#
#       angle_to_school  ps_wind_lat  ps_wind_lon  ps_wspd_merge  \
# 0  -55.29643968357893          NaN          NaN       1.531352
# 1  -55.29643968357893          NaN          NaN       1.531352
# 2  -37.54028477906731          NaN          NaN       1.531352
#
#    school_wdir_wrt_0N  ps_wdir_wrt_0N  school_wind_alignment  \
# 0          102.528057      102.528057             157.824497
# 1          102.528057      102.528057             157.824497
# 2          102.528057      102.528057             140.068342
#
#    ps_wind_alignment  avg_wind_speed  avg_wind_alignment  \
# 0         157.824497        1.531352          157.824497
# 1         157.824497        1.531352          157.824497
# 2         140.068342        1.531352          140.068342
#
#    avg_wind_alignment_cosine year_month_date  is_school_open
# 0                   0.073968      2010-04-01               1
# 1                   0.073968      2010-04-01               1
# 2                   0.233189      2010-04-01               1

# %%
# fix some datatypes
num_vars = ['angle_to_school', 'ps_elevation_m', 'pm25', 'point_source_pm25_tpy', 
            'dist_school_to_ps_m', 'angle_to_school', 'avg_wind_alignment_cosine']

for var in num_vars:
  df[var] = df[var].astype(float)

# %%
# filter out na pm2.5 values
df = df[~df['pm25'].isna()]

# just mean impute missing populations
df['pop_under19_male'] = df['pop_under19_male'].fillna(df['pop_under19_male'].mean())
df['pop_under19_female'] = df['pop_under19_female'].fillna(df['pop_under19_female'].mean())

# %% [markdown]
# # Aggregate data to zip/month level

# %%
# maybe not all of these should use 'mean', but doing it this way for now. 
mean_vars = ['school_wspd', 'school_elevation_m', 'ps_elevation_m', 'pop_under19_male', 
             'pop_under19_female', 'pm25', 'point_source_pm25_tpy', 'dist_school_to_ps_m', 
             'angle_to_school', 'ps_wspd_merge', 'school_wdir_wrt_0N', 'ps_wdir_wrt_0N', 
             'school_wind_alignment', 'ps_wind_alignment', 'avg_wind_speed', 
             'avg_wind_alignment', 'avg_wind_alignment_cosine']
mean_dict = {var:(var, 'mean') for var in mean_vars}

df_grp = df\
  .groupby(['year_month_date', 'school_county', 'school_region_name', 'school_zip'])\
  .agg(**mean_dict)\
  .reset_index()

df_grp.head(3)
# Out:
#   year_month_date school_county      school_region_name school_zip  \
# 0      2000-01-01       Alameda  San Francisco Bay Area      94501
# 1      2000-01-01       Alameda  San Francisco Bay Area      94502
# 2      2000-01-01       Alameda  San Francisco Bay Area      94514
#
#    school_wspd  school_elevation_m  ps_elevation_m  pop_under19_male  \
# 0     1.006650            6.142667        3.793333            6855.0
# 1     1.006650            4.655000        4.210000            1859.0
# 2     0.720902           27.460000      315.130000            1487.0
#
#    pop_under19_female       pm25  point_source_pm25_tpy  dist_school_to_ps_m  \
# 0              6497.0  14.600000               5.258067          1717.410608
# 1              1845.0  14.880000               9.449277          3018.878458
# 2              1294.0  20.241379             153.132229          7501.370079
#
#    angle_to_school  ps_wspd_merge  school_wdir_wrt_0N  ps_wdir_wrt_0N  \
# 0       -33.389362       0.628877           63.227197       68.462249
# 1      -139.679287       0.491505           63.227197       70.365905
# 2        57.048970       0.724224           57.298135       64.797385
#
#    school_wind_alignment  ps_wind_alignment  avg_wind_speed  \
# 0             140.776564         137.445167        0.817763
# 1             157.093516         149.954808        0.749077
# 2               0.249165           7.748415        0.722563
#
#    avg_wind_alignment  avg_wind_alignment_cosine
# 0          139.110866                   0.337179
# 1          153.524162                   0.113934
# 2            3.998790                   1.997562

# %% [markdown]
# ## Reminder: one hot encode school region name

# %% [markdown]
# hmmm strangly some values in the same zip code, will have diff county and regions...
#
# this example is simi valley

# %%
df_grp[(df_grp.year_month_date == datetime.strptime('2014-07-01', '%Y-%m-%d')) & (df_grp.school_zip == '93065')]
# Out:
#        year_month_date school_county           school_region_name school_zip  \
# 246248      2014-07-01        Fresno  Southern San Joaquin Valley      93065
# 246349      2014-07-01          Kern  Southern San Joaquin Valley      93065
# 246392      2014-07-01         Kings  Southern San Joaquin Valley      93065
# 246657      2014-07-01   Los Angeles           Los Angeles County      93065
# 247155      2014-07-01     San Diego         San Diego - Imperial      93065
# 247179      2014-07-01   San Joaquin  Northern San Joaquin Valley      93065
# 247224      2014-07-01     San Mateo       San Francisco Bay Area      93065
# 247384      2014-07-01        Sonoma                  North Coast      93065
# 247426      2014-07-01        Sutter          Superior California      93065
# 247517      2014-07-01       Ventura                Central Coast      93065
#
#         school_wspd  school_elevation_m  ps_elevation_m  pop_under19_male  \
# 246248     1.509139          217.770000          290.71          9052.446
# 246349     1.509139          217.770000          290.71          9052.446
# 246392     1.509139          217.770000          290.71          9052.446
# 246657     1.509139          217.770000          290.71          9052.446
# 247155     1.509139          217.770000          290.71          9052.446
# 247179     1.509139          217.770000          290.71          9052.446
# 247224     1.509139          217.770000          290.71          9052.446
# 247384     1.509139          217.770000          290.71          9052.446
# 247426     1.509139          217.770000          290.71          9052.446
# 247517     1.509139          267.094762          290.71          9052.446
#
#         pop_under19_female      pm25  point_source_pm25_tpy  \
# 246248            9445.244  9.053333               9.916024
# 246349            9445.244  9.053333               9.916024
# 246392            9445.244  9.053333               9.916024
# 246657            9445.244  9.053333               9.916024
# 247155            9445.244  9.053333               9.916024
# 247179            9445.244  9.053333               9.916024
# 247224            9445.244  9.053333               9.916024
# 247384            9445.244  9.053333               9.916024
# 247426            9445.244  9.053333               9.916024
# 247517            9445.244  9.053333               9.916024
#
#         dist_school_to_ps_m  angle_to_school  ps_wspd_merge  \
# 246248          1754.362438       163.471549       1.509139
# 246349          1754.362438       163.471549       1.509139
# 246392          1754.362438       163.471549       1.509139
# 246657          1754.362438       163.471549       1.509139
# 247155          1754.362438       163.471549       1.509139
# 247179          1754.362438       163.471549       1.509139
# 247224          1754.362438       163.471549       1.509139
# 247384          1754.362438       163.471549       1.509139
# 247426          1754.362438       163.471549       1.509139
# 247517          5040.601195       112.703179       1.509139
#
#         school_wdir_wrt_0N  ps_wdir_wrt_0N  school_wind_alignment  \
# 246248           47.089317       47.089317             116.382232
# 246349           47.089317       47.089317             116.382232
# 246392           47.089317       47.089317             116.382232
# 246657           47.089317       47.089317             116.382232
# 247155           47.089317       47.089317             116.382232
# 247179           47.089317       47.089317             116.382232
# 247224           47.089317       47.089317             116.382232
# 247384           47.089317       47.089317             116.382232
# 247426           47.089317       47.089317             116.382232
# 247517           47.089317       47.089317              82.756719
#
#         ps_wind_alignment  avg_wind_speed  avg_wind_alignment  \
# 246248         116.382232        1.509139          116.382232
# 246349         116.382232        1.509139          116.382232
# 246392         116.382232        1.509139          116.382232
# 246657         116.382232        1.509139          116.382232
# 247155         116.382232        1.509139          116.382232
# 247179         116.382232        1.509139          116.382232
# 247224         116.382232        1.509139          116.382232
# 247384         116.382232        1.509139          116.382232
# 247426         116.382232        1.509139          116.382232
# 247517          82.756719        1.509139           82.756719
#
#         avg_wind_alignment_cosine
# 246248                   0.555643
# 246349                   0.555643
# 246392                   0.555643
# 246657                   0.555643
# 247155                   0.555643
# 247179                   0.555643
# 247224                   0.555643
# 247384                   0.555643
# 247426                   0.555643
# 247517                   1.123762

# %%
# check NA
df_grp.isna().sum()
# Out:
# year_month_date              0
# school_county                0
# school_region_name           0
# school_zip                   0
# school_wspd                  0
# school_elevation_m           0
# ps_elevation_m               0
# pop_under19_male             0
# pop_under19_female           0
# pm25                         0
# point_source_pm25_tpy        0
# dist_school_to_ps_m          0
# angle_to_school              0
# ps_wspd_merge                0
# school_wdir_wrt_0N           0
# ps_wdir_wrt_0N               0
# school_wind_alignment        0
# ps_wind_alignment            0
# avg_wind_speed               0
# avg_wind_alignment           0
# avg_wind_alignment_cosine    0
# dtype: int64

# %% [markdown]
# # Grouping by Just Zipcode and month-year

# %%
df_grp_zip_year_only = df\
  .groupby(['year_month_date', 'school_zip'])\
  .agg(**mean_dict)\
  .reset_index()

df_grp_zip_year_only.head(3)
# Out:
#   year_month_date school_zip  school_wspd  school_elevation_m  ps_elevation_m  \
# 0      2000-01-01      90001     0.757031           44.728889       43.703333
# 1      2000-01-01      90002     0.757031           33.858889       29.690000
# 2      2000-01-01      90003     0.757031           42.329167       45.785000
#
#    pop_under19_male  pop_under19_female       pm25  point_source_pm25_tpy  \
# 0           12055.0             11450.0  32.149998              14.241154
# 1           10062.0              9781.0  31.849998               6.649500
# 2           12563.0             12233.0  31.724998              11.672797
#
#    dist_school_to_ps_m  angle_to_school  ps_wspd_merge  school_wdir_wrt_0N  \
# 0          3854.812685       -90.196586       0.757031         -172.758321
# 1          2734.278190       -75.730039       0.757031         -172.758321
# 2          5281.522927       -63.495073       0.855611         -172.758321
#
#    ps_wdir_wrt_0N  school_wind_alignment  ps_wind_alignment  avg_wind_speed  \
# 0     -172.758321              82.561735          82.561735        0.757031
# 1     -172.758321              97.028283          97.028283        0.757031
# 2      -60.057878             106.478652         100.850655        0.806321
#
#    avg_wind_alignment  avg_wind_alignment_cosine
# 0           82.561735                   1.124995
# 1           97.028283                   0.879819
# 2          103.664653                   0.869845

# %%
df_grp_zip_year_only.shape
# Out:
# (312789, 19)

# %%
df_grp_zip_year_only.columns
# Out:
# Index(['year_month_date', 'school_zip', 'school_wspd', 'school_elevation_m',
#        'ps_elevation_m', 'pop_under19_male', 'pop_under19_female', 'pm25',
#        'point_source_pm25_tpy', 'dist_school_to_ps_m', 'angle_to_school',
#        'ps_wspd_merge', 'school_wdir_wrt_0N', 'ps_wdir_wrt_0N',
#        'school_wind_alignment', 'ps_wind_alignment', 'avg_wind_speed',
#        'avg_wind_alignment', 'avg_wind_alignment_cosine'],
#       dtype='object')

# %% [markdown]
# # Modeling

# %% [markdown]
# ### A very baseline linear model

# %%
df_grp.pm25.hist(bins=50)
# Out:
# <AxesSubplot: >

# %%
df_grp['avg_wind_alignment_cosine_squared'] = df_grp['avg_wind_alignment_cosine']**2

display(df_grp[['avg_wind_alignment_cosine', 'avg_wind_alignment_cosine_squared']])
# Out:
#         avg_wind_alignment_cosine  avg_wind_alignment_cosine_squared
# 0                        0.337179                           0.113690
# 1                        0.113934                           0.012981
# 2                        1.997562                           3.990254
# 3                        0.844719                           0.713550
# 4                        1.527236                           2.332450
# ...                           ...                                ...
# 323357                   0.614988                           0.378210
# 323358                   1.266354                           1.603652
# 323359                   0.033526                           0.001124
# 323360                   1.677859                           2.815210
# 323361                   1.479848                           2.189949
#
# [323362 rows x 2 columns]

# %%
df_grp_zip_year_only['avg_wind_alignment_cosine_squared'] = (df_grp_zip_year_only['avg_wind_alignment_cosine']/2)**2

display(df_grp_zip_year_only[['avg_wind_alignment_cosine', 'avg_wind_alignment_cosine_squared']])
# Out:
#         avg_wind_alignment_cosine  avg_wind_alignment_cosine_squared
# 0                        1.124995                           0.316403
# 1                        0.879819                           0.193520
# 2                        0.869845                           0.189158
# 3                        1.160977                           0.336967
# 4                        0.923498                           0.213212
# ...                           ...                                ...
# 312784                   0.203923                           0.010396
# 312785                   0.450580                           0.050756
# 312786                   1.594435                           0.635556
# 312787                   1.677660                           0.703636
# 312788                   1.901552                           0.903975
#
# [312789 rows x 2 columns]

# %%
x_vars = ['school_elevation_m', 'ps_elevation_m', 'pop_under19_male', 
          'pop_under19_female', 'dist_school_to_ps_m',
          'avg_wind_speed', 'avg_wind_alignment_cosine']

X = df_grp_zip_year_only[x_vars]
y = df_grp_zip_year_only['pm25']

# %%
# add constant
X = sm.add_constant(X)

# fit
est = sm.OLS(y, X).fit()

# see summary
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   pm25   R-squared:                       0.182
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     9969.
# Date:                Wed, 05 Oct 2022   Prob (F-statistic):               0.00
# Time:                        22:07:53   Log-Likelihood:            -9.7200e+05
# No. Observations:              312789   AIC:                         1.944e+06
# Df Residuals:                  312781   BIC:                         1.944e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        11.4581      0.030    377.376      0.000      11.399      11.518
# school_elevation_m           -0.0018   5.59e-05    -32.937      0.000      -0.002      -0.002
# ps_elevation_m               -0.0010   5.83e-05    -17.254      0.000      -0.001      -0.001
# pop_under19_male              0.0002   3.26e-05      5.340      0.000       0.000       0.000
# pop_under19_female            0.0002   3.41e-05      7.070      0.000       0.000       0.000
# dist_school_to_ps_m        -7.71e-05   8.84e-07    -87.251      0.000   -7.88e-05   -7.54e-05
# avg_wind_speed               -1.4223      0.013   -106.571      0.000      -1.448      -1.396
# avg_wind_alignment_cosine     0.1506      0.017      9.117      0.000       0.118       0.183
# ==============================================================================
# Omnibus:                   136153.099   Durbin-Watson:                   0.439
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1161865.349
# Skew:                           1.889   Prob(JB):                         0.00
# Kurtosis:                      11.653   Cond. No.                     5.34e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.34e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# print RMSE
rmse_residuals = np.sqrt(est.mse_resid)
print(rmse_residuals)
# Out:
# 5.411868489996161

# %%
pm25_pred = est.predict(X)

# %%
pm25_pred.hist(bins=50)
# Out:
# <AxesSubplot: >
